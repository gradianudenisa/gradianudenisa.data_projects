# %% [markdown]
# ## Project - Popular DS Questions StackExchange

# %% [markdown]
# The aim of the following analysis is to use Data Science Stack Exchange to determine what content should a data science education company create, based on the interest by subject. In Stack Exchange each post, meaning each question/answer — is subject to upvotes and downvotes. This makes good posts easily identifiable.Stack Exchange provides a public data base for each of its websites. Here's a [link](https://data.stackexchange.com/datascience/query/new) to query and explore Data Science Stack Exchange's database.
#
# ![Image](https://dq-content.s3.amazonaws.com/469/dsde.png)
#
# We will use the __posts__ table since the tags columns is useful in categorzing the content. Some columns that are relevant for our goal:
#
# `Id`: An identification number for the post.
#
# `PostTypeId`: An identification number for the type of post.
#
# `CreationDate`: The date and time of creation of the post.
#
# `Score`: The post's score.
#
# `ViewCount`: How many times the post was viewed.
#
# `Tags`: What tags were used.
#
# `AnswerCount`: How many answers the question got (only applicable to question posts).
#
# `FavoriteCount`: How many times the question was favored (only applicable to question posts).
#
# We'll limit our analysis to the posts of 2019.

# %% [markdown]
# ### Getting the Data

# %% [markdown]
# To get the data we need te run the follwoing query against the Data Science Stack Exchange's database.
#
# `SELECT Id, CreationDate,
#        Score, ViewCount, Tags,
#        AnswerCount, FavoriteCount
#   FROM posts
#  WHERE PostTypeId = 1 AND YEAR(CreationDate) = 2019;`

# %% [markdown]
# ![Image](https://images.unsplash.com/photo-1460925895917-afdab827c52f?ixlib=rb-4.0.3&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=2015&q=80)
# _Photo by Carlos Muza on Unsplash_

# %% [markdown]
# ### Exploring the Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
questions=pd.read_csv("C:/Users/Denisa/Desktop/Project Apps/project 11/QueryResults.csv", parse_dates=["CreationDate"])

# %%
questions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6751 entries, 0 to 6750
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             6751 non-null   int64
#  1   CreationDate   6751 non-null   datetime64[ns]
#  2   Score          6751 non-null   int64
#  3   ViewCount      6751 non-null   int64
#  4   Tags           6751 non-null   object
#  5   AnswerCount    6751 non-null   int64
#  6   FavoriteCount  160 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(1)
# memory usage: 369.3+ KB

# %% [markdown]
# We can see that the column named _FavoriteCount_ has missing values. The data types seem appropriate, but for _Tags_, we should investigate further and establish with more precison what types the objects in the columns are. Also _FavoriteCount_ should be converted to int.

# %%
questions.head()
# Out:
#       Id        CreationDate  Score  ViewCount  \
# 0  60124 2019-09-12 16:00:22      1         38
# 1  60126 2019-09-12 17:34:38      1       4589
# 2  60127 2019-09-12 17:51:00      2       1252
# 3  60128 2019-09-12 17:51:29      1          9
# 4  60129 2019-09-12 18:10:24      1         31
#
#                                                 Tags  AnswerCount  \
# 0                                       <algorithms>            0
# 1                           <python><keras><reshape>            2
# 2                                       <tensorflow>            0
# 3  <image-classification><computer-vision><image-...            0
# 4  <machine-learning><recommender-system><transfe...            0
#
#    FavoriteCount
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
questions["Tags"].apply(lambda value: type(value))
# Out:
# 0       <class 'str'>
# 1       <class 'str'>
# 2       <class 'str'>
# 3       <class 'str'>
# 4       <class 'str'>
#             ...
# 6746    <class 'str'>
# 6747    <class 'str'>
# 6748    <class 'str'>
# 6749    <class 'str'>
# 6750    <class 'str'>
# Name: Tags, Length: 6751, dtype: object

# %% [markdown]
# ### Cleaning the Data

# %%
#Fill in the missing values with 0
questions.fillna(0, inplace=True)

# %% [markdown]
# We want to transform the values in questions["Tags"] in something more suitable to use typical string methods. We will transform and clean the column and after the process that we just illustrated, we will split on `,` to obtain a list.

# %%
questions["Tags"]=questions["Tags"].str.replace("<","")
questions["Tags"]=questions["Tags"].str.replace(">"," ")
questions["Tags"]=questions["Tags"].str.split()

# %%
questions["FavoriteCount"] = questions["FavoriteCount"].astype(int)

# %%
questions
# Out:
#          Id        CreationDate  Score  ViewCount  \
# 0     60124 2019-09-12 16:00:22      1         38
# 1     60126 2019-09-12 17:34:38      1       4589
# 2     60127 2019-09-12 17:51:00      2       1252
# 3     60128 2019-09-12 17:51:29      1          9
# 4     60129 2019-09-12 18:10:24      1         31
# ...     ...                 ...    ...        ...
# 6746  60108 2019-09-12 10:03:44      1         45
# 6747  60112 2019-09-12 11:05:10      3        380
# 6748  60113 2019-09-12 11:13:22      0        997
# 6749  60119 2019-09-12 13:30:23      3        152
# 6750  60122 2019-09-12 15:15:27      1        402
#
#                                                    Tags  AnswerCount  \
# 0                                          [algorithms]            0
# 1                              [python, keras, reshape]            2
# 2                                          [tensorflow]            0
# 3     [image-classification, computer-vision, image-...            0
# 4     [machine-learning, recommender-system, transfe...            0
# ...                                                 ...          ...
# 6746                                              [svm]            1
# 6747         [categorical-data, missing-data, encoding]            1
# 6748         [python, pandas, data-cleaning, dataframe]            3
# 6749              [python, scikit-learn, pandas, numpy]            1
# 6750  [python, deep-learning, keras, class-imbalance...            0
#
#       FavoriteCount
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 6746              0
# 6747              0
# 6748              0
# 6749              0
# 6750              0
#
# [6751 rows x 7 columns]

# %%
questions.dtypes
# Out:
# Id                        int64
# CreationDate     datetime64[ns]
# Score                     int64
# ViewCount                 int64
# Tags                     object
# AnswerCount               int64
# FavoriteCount             int32
# dtype: object

# %% [markdown]
# ### Most Used and Most Viewed Tags
# To determine the most popular tags, we will use two proxies: the number of times each tag was used, and how many times a question with that tag was viewed.

# %%
#Counting how many times each tag was used
tag_count = dict()

for tags in questions["Tags"]:
    for tag in tags:
        if tag in tag_count:
            tag_count[tag] += 1
        else:
            tag_count[tag] = 1

# %%
tag_count = pd.DataFrame.from_dict(tag_count, orient="index")
tag_count.rename(columns={0: "Count"}, inplace=True)
tag_count.head(10)
# Out:
#                       Count
# algorithms               48
# python                 1438
# keras                   705
# reshape                   6
# tensorflow              409
# image-classification    161
# computer-vision          89
# image-recognition        56
# machine-learning       2127
# recommender-system       65

# %%
most_used = tag_count.sort_values(by="Count").tail(20)
most_used
# Out:
#                         Count
# machine-learning-model    172
# feature-selection         175
# r                         194
# predictive-modeling       211
# clustering                229
# dataset                   245
# regression                269
# lstm                      287
# pandas                    315
# time-series               334
# cnn                       378
# tensorflow                409
# nlp                       443
# scikit-learn              448
# classification            577
# keras                     705
# neural-network            823
# deep-learning             895
# python                   1438
# machine-learning         2127

# %%
most_used.plot(kind="barh", figsize=(16,8), title='Counting how many times each tag was used')
# Out:
# <AxesSubplot:title={'center':'Counting how many times each tag was used'}>

# %%
#Counting how many times each tag was viewed
tag_view_count = dict()

for index, row in questions.iterrows():
    for tag in row['Tags']:
        if tag in tag_view_count:
            tag_view_count[tag] += row['ViewCount']
        else:
            tag_view_count[tag] = row['ViewCount']
            
tag_view_count = pd.DataFrame.from_dict(tag_view_count, orient="index")
tag_view_count.rename(columns={0: "ViewCount"}, inplace=True)

most_viewed = tag_view_count.sort_values(by="ViewCount").tail(20)

most_viewed.plot(kind="barh", figsize=(16,8), title='Counting how many times each tag was viewed')
# Out:
# <AxesSubplot:title={'center':'Counting how many times each tag was viewed'}>

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
fig.set_size_inches((24, 10))
most_used.plot(kind="barh", ax=axes[0], subplots=True)
most_viewed.plot(kind="barh", ax=axes[1], subplots=True)
# Out:
# array([<AxesSubplot:title={'center':'ViewCount'}>], dtype=object)

# %% [markdown]
# ### Relations Between Tags

# %% [markdown]
# We can see that most top tags are present in both dataframes.To see what tags are in most_used, but not in most_viewed and the other way around, we can identify them by the missing values using the pd.merge() method.

# %%
pd.merge(most_used, most_viewed, how="left", left_index=True, right_index=True)
# Out:
#                         Count  ViewCount
# machine-learning-model    172        NaN
# feature-selection         175        NaN
# r                         194        NaN
# predictive-modeling       211        NaN
# clustering                229        NaN
# dataset                   245   263802.0
# regression                269   332077.0
# lstm                      287   437091.0
# pandas                    315  1754184.0
# time-series               334   416942.0
# cnn                       378   635343.0
# tensorflow                409   853997.0
# nlp                       443   612824.0
# scikit-learn              448  1026456.0
# classification            577   751158.0
# keras                     705  1590763.0
# neural-network            823  1401878.0
# deep-learning             895  1495216.0
# python                   1438  3740720.0
# machine-learning         2127  2679966.0

# %%
pd.merge(most_used, most_viewed, how="right", left_index=True, right_index=True)
# Out:
#                    Count  ViewCount
# dataset            245.0     263802
# bert                 NaN     274240
# xgboost              NaN     284139
# pytorch              NaN     330152
# regression         269.0     332077
# numpy                NaN     390664
# time-series        334.0     416942
# lstm               287.0     437091
# nlp                443.0     612824
# dataframe            NaN     614365
# cnn                378.0     635343
# classification     577.0     751158
# tensorflow         409.0     853997
# scikit-learn       448.0    1026456
# neural-network     823.0    1401878
# deep-learning      895.0    1495216
# keras              705.0    1590763
# pandas             315.0    1754184
# machine-learning  2127.0    2679966
# python            1438.0    3740720

# %% [markdown]
# The tags present in most_used and not present in most_viewed are:
# * machine-learning-model
# * statistics
# * predictive-modeling
# * r
#
# And the tags present in most_viewed but not in most_used are:
#
# * csv
# * pytorch
# * dataframe

# %% [markdown]
# To determine how pairs of tags are related to each other, we will count how many times each pair appears together.

# %%
all_tags = list(tag_count.index)

# %%
associations = pd.DataFrame(index=all_tags, columns=all_tags)
associations
# Out:
#                           algorithms python keras reshape tensorflow  \
# algorithms                       NaN    NaN   NaN     NaN        NaN
# python                           NaN    NaN   NaN     NaN        NaN
# keras                            NaN    NaN   NaN     NaN        NaN
# reshape                          NaN    NaN   NaN     NaN        NaN
# tensorflow                       NaN    NaN   NaN     NaN        NaN
# ...                              ...    ...   ...     ...        ...
# redshift                         NaN    NaN   NaN     NaN        NaN
# data-indexing-techniques         NaN    NaN   NaN     NaN        NaN
# multivariate-distribution        NaN    NaN   NaN     NaN        NaN
# open-source                      NaN    NaN   NaN     NaN        NaN
# history                          NaN    NaN   NaN     NaN        NaN
#
#                           image-classification computer-vision  \
# algorithms                                 NaN             NaN
# python                                     NaN             NaN
# keras                                      NaN             NaN
# reshape                                    NaN             NaN
# tensorflow                                 NaN             NaN
# ...                                        ...             ...
# redshift                                   NaN             NaN
# data-indexing-techniques                   NaN             NaN
# multivariate-distribution                  NaN             NaN
# open-source                                NaN             NaN
# history                                    NaN             NaN
#
#                           image-recognition machine-learning  \
# algorithms                              NaN              NaN
# python                                  NaN              NaN
# keras                                   NaN              NaN
# reshape                                 NaN              NaN
# tensorflow                              NaN              NaN
# ...                                     ...              ...
# redshift                                NaN              NaN
# data-indexing-techniques                NaN              NaN
# multivariate-distribution               NaN              NaN
# open-source                             NaN              NaN
# history                                 NaN              NaN
#
#                           recommender-system  ... crawling movielens momentum  \
# algorithms                               NaN  ...      NaN       NaN      NaN
# python                                   NaN  ...      NaN       NaN      NaN
# keras                                    NaN  ...      NaN       NaN      NaN
# reshape                                  NaN  ...      NaN       NaN      NaN
# tensorflow                               NaN  ...      NaN       NaN      NaN
# ...                                      ...  ...      ...       ...      ...
# redshift                                 NaN  ...      NaN       NaN      NaN
# data-indexing-techniques                 NaN  ...      NaN       NaN      NaN
# multivariate-distribution                NaN  ...      NaN       NaN      NaN
# open-source                              NaN  ...      NaN       NaN      NaN
# history                                  NaN  ...      NaN       NaN      NaN
#
#                           allennlp manifold redshift data-indexing-techniques  \
# algorithms                     NaN      NaN      NaN                      NaN
# python                         NaN      NaN      NaN                      NaN
# keras                          NaN      NaN      NaN                      NaN
# reshape                        NaN      NaN      NaN                      NaN
# tensorflow                     NaN      NaN      NaN                      NaN
# ...                            ...      ...      ...                      ...
# redshift                       NaN      NaN      NaN                      NaN
# data-indexing-techniques       NaN      NaN      NaN                      NaN
# multivariate-distribution      NaN      NaN      NaN                      NaN
# open-source                    NaN      NaN      NaN                      NaN
# history                        NaN      NaN      NaN                      NaN
#
#                           multivariate-distribution open-source history
# algorithms                                      NaN         NaN     NaN
# python                                          NaN         NaN     NaN
# keras                                           NaN         NaN     NaN
# reshape                                         NaN         NaN     NaN
# tensorflow                                      NaN         NaN     NaN
# ...                                             ...         ...     ...
# redshift                                        NaN         NaN     NaN
# data-indexing-techniques                        NaN         NaN     NaN
# multivariate-distribution                       NaN         NaN     NaN
# open-source                                     NaN         NaN     NaN
# history                                         NaN         NaN     NaN
#
# [489 rows x 489 columns]

# %%
associations.fillna(0, inplace=True)

for tags in questions["Tags"]:
    associations.loc[tags, tags] += 1
print(associations[:4])
# Out:
#             algorithms  python  keras  reshape  tensorflow  \
# algorithms          48       6      0        0           1
# python               6    1438    204        2         119
# keras                0     204    705        2         196
# reshape              0       2      2        6           0
#
#             image-classification  computer-vision  image-recognition  \
# algorithms                     0                0                  0
# python                        21               19                  5
# keras                         37               11                  4
# reshape                        0                0                  0
#
#             machine-learning  recommender-system  ...  crawling  movielens  \
# algorithms                23                   0  ...         0          0
# python                   401                  10  ...         1          0
# keras                    147                   2  ...         0          0
# reshape                    0                   0  ...         0          0
#
#             momentum  allennlp  manifold  redshift  data-indexing-techniques  \
# algorithms         0         0         0         0                         0
# python             0         0         0         0                         1
# keras              0         0         1         0                         0
# reshape            0         0         0         0                         0
#
#             multivariate-distribution  open-source  history
# algorithms                          0            0        0
# python                              0            0        0
# keras                               0            0        0
# reshape                             0            0        0
#
# [4 rows x 489 columns]

# %%
#We will focus only on the most used tags
relations_most_used = associations.loc[most_used.index, most_used.index]

def style_cells(x):
    helper_df = pd.DataFrame('', index=x.index, columns=x.columns)
    helper_df.loc["time-series", "r"] = "background-color: yellow"
    helper_df.loc["r", "time-series"] = "background-color: yellow"
    for k in range(helper_df.shape[0]):
        helper_df.iloc[k,k] = "color: blue"
    
    return helper_df

relations_most_used.style.apply(style_cells, axis=None)
# Out:
# <style  type="text/css" >
# #T_b4dc6_row0_col0,#T_b4dc6_row1_col1,#T_b4dc6_row2_col2,#T_b4dc6_row3_col3,#T_b4dc6_row4_col4,#T_b4dc6_row5_col5,#T_b4dc6_row6_col6,#T_b4dc6_row7_col7,#T_b4dc6_row8_col8,#T_b4dc6_row9_col9,#T_b4dc6_row10_col10,#T_b4dc6_row11_col11,#T_b4dc6_row12_col12,#T_b4dc6_row13_col13,#T_b4dc6_row14_col14,#T_b4dc6_row15_col15,#T_b4dc6_row16_col16,#T_b4dc6_row17_col17,#T_b4dc6_row18_col18,#T_b4dc6_row19_col19{
#             color:  blue;
#         }#T_b4dc6_row2_col9,#T_b4dc6_row9_col2{
#             background-color:  yellow;
#         }</style><table id="T_b4dc6_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >machine-learning-model</th>        <th class="col_heading level0 col1" >feature-selection</th>        <th class="col_heading level0 col2" >r</th>        <th class="col_heading level0 col3" >predictive-modeling</th>        <th class="col_heading level0 col4" >clustering</th>        <th class="col_heading level0 col5" >dataset</th>        <th class="col_heading level0 col6" >regression</th>        <th class="col_heading level0 col7" >lstm</th>        <th class="col_heading level0 col8" >pandas</th>        <th class="col_heading level0 col9" >time-series</th>        <th class="col_heading level0 col10" >cnn</th>        <th class="col_heading level0 col11" >tensorflow</th>        <th class="col_heading level0 col12" >nlp</th>        <th class="col_heading level0 col13" >scikit-learn</th>        <th class="col_heading level0 col14" >classification</th>        <th class="col_heading level0 col15" >keras</th>        <th class="col_heading level0 col16" >neural-network</th>        <th class="col_heading level0 col17" >deep-learning</th>        <th class="col_heading level0 col18" >python</th>        <th class="col_heading level0 col19" >machine-learning</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b4dc6_level0_row0" class="row_heading level0 row0" >machine-learning-model</th>
#                         <td id="T_b4dc6_row0_col0" class="data row0 col0" >172</td>
#                         <td id="T_b4dc6_row0_col1" class="data row0 col1" >7</td>
#                         <td id="T_b4dc6_row0_col2" class="data row0 col2" >5</td>
#                         <td id="T_b4dc6_row0_col3" class="data row0 col3" >17</td>
#                         <td id="T_b4dc6_row0_col4" class="data row0 col4" >3</td>
#                         <td id="T_b4dc6_row0_col5" class="data row0 col5" >10</td>
#                         <td id="T_b4dc6_row0_col6" class="data row0 col6" >5</td>
#                         <td id="T_b4dc6_row0_col7" class="data row0 col7" >3</td>
#                         <td id="T_b4dc6_row0_col8" class="data row0 col8" >1</td>
#                         <td id="T_b4dc6_row0_col9" class="data row0 col9" >5</td>
#                         <td id="T_b4dc6_row0_col10" class="data row0 col10" >3</td>
#                         <td id="T_b4dc6_row0_col11" class="data row0 col11" >6</td>
#                         <td id="T_b4dc6_row0_col12" class="data row0 col12" >5</td>
#                         <td id="T_b4dc6_row0_col13" class="data row0 col13" >15</td>
#                         <td id="T_b4dc6_row0_col14" class="data row0 col14" >21</td>
#                         <td id="T_b4dc6_row0_col15" class="data row0 col15" >12</td>
#                         <td id="T_b4dc6_row0_col16" class="data row0 col16" >9</td>
#                         <td id="T_b4dc6_row0_col17" class="data row0 col17" >11</td>
#                         <td id="T_b4dc6_row0_col18" class="data row0 col18" >27</td>
#                         <td id="T_b4dc6_row0_col19" class="data row0 col19" >105</td>
#             </tr>
#             <tr>
#                         <th id="T_b4dc6_level0_row1" class="row_heading level0 row1" >feature-selection</th>
#                         <td id="T_b4dc6_row1_col0" class="data row1 col0" >7</td>
#                         <td id="T_b4dc6_row1_col1" class="data row1 col1" >175</td>
#                         <td id="T_b4dc6_row1_col2" class="data row1 col2" >5</td>
#                         <td id="T_b4dc6_row1_col3" class="data row1 col3" >16</td>
#                         <td id="T_b4dc6_row1_col4" class="data row1 col4" >3</td>
#                         <td id="T_b4dc6_row1_col5" class="data row1 col5" >4</td>
#                         <td id="T_b4dc6_row1_col6" class="data row1 col6" >10</td>
#                         <td id="T_b4dc6_row1_col7" class="data row1 col7" >1</td>
#                         <td id="T_b4dc6_row1_col8" class="data row1 col8" >2</td>
#                         <td id="T_b4dc6_row1_col9" class="data row1 col9" >6</td>
#                         <td id="T_b4dc6_row1_col10" class="data row1 col10" >1</td>
#                         <td id="T_b4dc6_row1_col11" class="data row1 col11" >0</td>
#                         <td id="T_b4dc6_row1_col12" class="data row1 col12" >4</td>
#                         <td id="T_b4dc6_row1_col13" class="data row1 col13" >19</td>
#                         <td id="T_b4dc6_row1_col14" class="data row1 col14" >17</td>
#                         <td id="T_b4dc6_row1_col15" class="data row1 col15" >1</td>
#                         <td id="T_b4dc6_row1_col16" class="data row1 col16" >7</td>
#                         <td id="T_b4dc6_row1_col17" class="data row1 col17" >18</td>
#                         <td id="T_b4dc6_row1_col18" class="data row1 col18" >23</td>
#                         <td id="T_b4dc6_row1_col19" class="data row1 col19" >81</td>
#             </tr>
#             <tr>
#                         <th id="T_b4dc6_level0_row2" class="row_heading level0 row2" >r</th>
#                         <td id="T_b4dc6_row2_col0" class="data row2 col0" >5</td>
#                         <td id="T_b4dc6_row2_col1" class="data row2 col1" >5</td>
#                         <td id="T_b4dc6_row2_col2" class="data row2 col2" >194</td>
#                         <td id="T_b4dc6_row2_col3" class="data row2 col3" >11</td>
#                         <td id="T_b4dc6_row2_col4" class="data row2 col4" >16</td>
#                         <td id="T_b4dc6_row2_col5" class="data row2 col5" >5</td>
#                         <td id="T_b4dc6_row2_col6" class="data row2 col6" >7</td>
#                         <td id="T_b4dc6_row2_col7" class="data row2 col7" >3</td>
#                         <td id="T_b4dc6_row2_col8" class="data row2 col8" >1</td>
#                         <td id="T_b4dc6_row2_col9" class="data row2 col9" >18</td>
#                         <td id="T_b4dc6_row2_col10" class="data row2 col10" >1</td>
#                         <td id="T_b4dc6_row2_col11" class="data row2 col11" >1</td>
#                         <td id="T_b4dc6_row2_col12" class="data row2 col12" >3</td>
#                         <td id="T_b4dc6_row2_col13" class="data row2 col13" >1</td>
#                         <td id="T_b4dc6_row2_col14" class="data row2 col14" >8</td>
#                         <td id="T_b4dc6_row2_col15" class="data row2 col15" >8</td>
#                         <td id="T_b4dc6_row2_col16" class="data row2 col16" >6</td>
#                         <td id="T_b4dc6_row2_col17" class="data row2 col17" >4</td>
#                         <td id="T_b4dc6_row2_col18" class="data row2 col18" >19</td>
#                         <td id="T_b4dc6_row2_col19" class="data row2 col19" >48</td>
#             </tr>
#             <tr>
#                         <th id="T_b4dc6_level0_row3" class="row_heading level0 row3" >predictive-modeling</th>
#                         <td id="T_b4dc6_row3_col0" class="data row3 col0" >17</td>
#                         <td id="T_b4dc6_row3_col1" class="data row3 col1" >16</td>
#                         <td id="T_b4dc6_row3_col2" class="data row3 col2" >11</td>
#                         <td id="T_b4dc6_row3_col3" class="data row3 col3" >211</td>
#                         <td id="T_b4dc6_row3_col4" class="data row3 col4" >0</td>
#                         <td id="T_b4dc6_row3_col5" class="data row3 col5" >5</td>
#                         <td id="T_b4dc6_row3_col6" class="data row3 col6

# %%
for i in range(relations_most_used.shape[0]):
    relations_most_used.iloc[i,i] = np.NaN

# %%
plt.figure(figsize=(12,8))
sns.heatmap(relations_most_used, cmap="Reds", annot=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# It seems like python, ML, deep-learning, neural-network are the mpst popular topics in the DS field on Stack Exchange.

# %% [markdown]
# ### Further investigating deep-learning

# %% [markdown]
# Next we want to see if the interest in deep-learning could be slowing down, meaning if it was just a fad in 2019. For this we will analyze a dataset containing all the questions ever asked on DSSE, alon gwith their dates and tags.

# %%
all_questions=pd.read_csv("C:/Users/Denisa/Desktop/Project Apps/project 11/all_questions.csv", parse_dates=["CreationDate"])
all_questions
# Out:
#           Id        CreationDate  \
# 0      45416 2019-02-12 00:36:29
# 1      45418 2019-02-12 00:50:39
# 2      45422 2019-02-12 04:40:51
# 3      45426 2019-02-12 04:51:49
# 4      45427 2019-02-12 05:08:24
# ...      ...                 ...
# 21571  36971 2018-08-15 14:19:01
# 21572  36974 2018-08-15 14:40:27
# 21573  36975 2018-08-15 14:53:43
# 21574  36979 2018-08-14 19:31:43
# 21575  36985 2018-08-15 17:01:29
#
#                                                     Tags
# 0          <python><keras><tensorflow><cnn><probability>
# 1                                       <neural-network>
# 2                          <python><ibm-watson><chatbot>
# 3                                                <keras>
# 4      <r><predictive-modeling><machine-learning-mode...
# ...                                                  ...
# 21571                                 <statistics><data>
# 21572     <machine-learning><neural-network><classifier>
# 21573                 <machine-learning><classification>
# 21574                               <tensorflow><python>
# 21575                <python><deep-learning><tensorflow>
#
# [21576 rows x 3 columns]

# %%
#We will clean the Tags columns same as before.

all_questions["Tags"]=all_questions["Tags"].str.replace("<","")
all_questions["Tags"]=all_questions["Tags"].str.replace(">"," ")
all_questions["Tags"]=all_questions["Tags"].str.split()

# %% [markdown]
# We will consider a deep learning tag as being a tag that belongs to the list ["lstm", "cnn", "scikit-learn", "tensorflow", "keras", "neural-network", "deep-learning"].This list was obtained by looking at all the tags in most_used and seeing which ones had any relation to deep learning. We'll now create a function that assigns 1 to deep learning questions and 0 otherwise.

# %%
def deep_learning(tags):
    for tag in tags:
        if tag in ["lstm", "cnn", "scikit-learn", "tensorflow",
                   "keras", "neural-network", "deep-learning"]:
            return 1
    return 0

# %%
all_questions["DeepLearning"] = all_questions["Tags"].apply(deep_learning)
all_questions
# Out:
#           Id        CreationDate  \
# 0      45416 2019-02-12 00:36:29
# 1      45418 2019-02-12 00:50:39
# 2      45422 2019-02-12 04:40:51
# 3      45426 2019-02-12 04:51:49
# 4      45427 2019-02-12 05:08:24
# ...      ...                 ...
# 21571  36971 2018-08-15 14:19:01
# 21572  36974 2018-08-15 14:40:27
# 21573  36975 2018-08-15 14:53:43
# 21574  36979 2018-08-14 19:31:43
# 21575  36985 2018-08-15 17:01:29
#
#                                                     Tags  DeepLearning
# 0          [python, keras, tensorflow, cnn, probability]             1
# 1                                       [neural-network]             1
# 2                          [python, ibm-watson, chatbot]             0
# 3                                                [keras]             1
# 4      [r, predictive-modeling, machine-learning-mode...             0
# ...                                                  ...           ...
# 21571                                 [statistics, data]             0
# 21572     [machine-learning, neural-network, classifier]             1
# 21573                 [machine-learning, classification]             0
# 21574                               [tensorflow, python]             1
# 21575                [python, deep-learning, tensorflow]             1
#
# [21576 rows x 4 columns]

# %% [markdown]
# Next we will add a new columns that identifies the quarter of every year for each post

# %%
all_questions = all_questions[all_questions["CreationDate"].dt.year < 2020].copy()

# %%
def fetch_quarter(datetime):
    year = str(datetime.year)[-2:]
    quarter = str(((datetime.month-1) // 3) + 1)
    return "{y}Q{q}".format(y=year, q=quarter)

# %%
all_questions["Quarter"] = all_questions["CreationDate"].apply(fetch_quarter)
all_questions
# Out:
#           Id        CreationDate  \
# 0      45416 2019-02-12 00:36:29
# 1      45418 2019-02-12 00:50:39
# 2      45422 2019-02-12 04:40:51
# 3      45426 2019-02-12 04:51:49
# 4      45427 2019-02-12 05:08:24
# ...      ...                 ...
# 21571  36971 2018-08-15 14:19:01
# 21572  36974 2018-08-15 14:40:27
# 21573  36975 2018-08-15 14:53:43
# 21574  36979 2018-08-14 19:31:43
# 21575  36985 2018-08-15 17:01:29
#
#                                                     Tags  DeepLearning Quarter
# 0          [python, keras, tensorflow, cnn, probability]             1    19Q1
# 1                                       [neural-network]             1    19Q1
# 2                          [python, ibm-watson, chatbot]             0    19Q1
# 3                                                [keras]             1    19Q1
# 4      [r, predictive-modeling, machine-learning-mode...             0    19Q1
# ...                                                  ...           ...     ...
# 21571                                 [statistics, data]             0    18Q3
# 21572     [machine-learning, neural-network, classifier]             1    18Q3
# 21573                 [machine-learning, classification]             0    18Q3
# 21574                               [tensorflow, python]             1    18Q3
# 21575                [python, deep-learning, tensorflow]             1    18Q3
#
# [21117 rows x 5 columns]

# %%
all_questions
# Out:
#           Id        CreationDate  \
# 0      45416 2019-02-12 00:36:29
# 1      45418 2019-02-12 00:50:39
# 2      45422 2019-02-12 04:40:51
# 3      45426 2019-02-12 04:51:49
# 4      45427 2019-02-12 05:08:24
# ...      ...                 ...
# 21571  36971 2018-08-15 14:19:01
# 21572  36974 2018-08-15 14:40:27
# 21573  36975 2018-08-15 14:53:43
# 21574  36979 2018-08-14 19:31:43
# 21575  36985 2018-08-15 17:01:29
#
#                                                     Tags  DeepLearning Quarter
# 0          [python, keras, tensorflow, cnn, probability]             1    19Q1
# 1                                       [neural-network]             1    19Q1
# 2                          [python, ibm-watson, chatbot]             0    19Q1
# 3                                                [keras]             1    19Q1
# 4      [r, predictive-modeling, machine-learning-mode...             0    19Q1
# ...                                                  ...           ...     ...
# 21571                                 [statistics, data]             0    18Q3
# 21572     [machine-learning, neural-network, classifier]             1    18Q3
# 21573                 [machine-learning, classification]             0    18Q3
# 21574                               [tensorflow, python]             1    18Q3
# 21575                [python, deep-learning, tensorflow]             1    18Q3
#
# [21117 rows x 5 columns]

# %% [markdown]
# Next we'll group by quarter and:
#
# * Count the number of deep learning questions.
# * Count the total number of questions.
# * Compute the ratio between them.

# %%
quarterly = all_questions.groupby('Quarter').agg({"DeepLearning": ['sum', 'size']})
quarterly.columns = ['DeepLearningQuestions', 'TotalQuestions']
quarterly["DeepLearningRate"] = quarterly["DeepLearningQuestions"]\
                                /quarterly["TotalQuestions"]

quarterly.reset_index(inplace=True)
quarterly.head()
# Out:
#   Quarter  DeepLearningQuestions  TotalQuestions  DeepLearningRate
# 0    14Q2                      9             157          0.057325
# 1    14Q3                     13             189          0.068783
# 2    14Q4                     21             216          0.097222
# 3    15Q1                     18             190          0.094737
# 4    15Q2                     28             284          0.098592

# %%
ax1 = quarterly.plot(x="Quarter", y="DeepLearningRate",
                    kind="line", linestyle="-", marker="o", color="orange",
                    figsize=(24,12)
                    )

ax2 = quarterly.plot(x="Quarter", y="TotalQuestions",
                     kind="bar", ax=ax1, secondary_y=True, alpha=0.7, rot=45)
for idx, t in quarterly["TotalQuestions"].iteritems():
    ax2.text(idx, t, str(t), ha="center", va="bottom")
xlims = ax1.get_xlim()

ax1.get_legend().remove()
handles1, labels1 = ax1.get_legend_handles_labels()
handles2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(handles=handles1 + handles2,
           labels=labels1 + labels2,
           loc="upper left", prop={"size": 12})


for ax in (ax1, ax2):
    for where in ("top", "right"):
        ax.spines[where].set_visible(False)
        ax.tick_params(right=False, labelright=False)

# %% [markdown]
# From the visualisation abobe it seems like the topic of deep-learning was not just a fad and has the potential to grow.
